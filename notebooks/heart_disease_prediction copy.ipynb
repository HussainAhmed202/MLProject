# %% [markdown]
# # Heart Diseases Prediction - ML Project
# #### **Roll No.**
#
# *CS21092*
#
# *CS21083*
#
# *CS21077*

# %% [markdown]
# ## About the dataset
#
#
# https://archive.ics.uci.edu/dataset/45/heart+disease
#
# ![intro.png](data:image/png;base64,...)

# %%
# import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Get the data

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\pc world\anaconda3\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\pc world\anaconda3\lib\site-packages (from ucimlrepo) (2.1.4)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\pc world\anaconda3\lib\site-packages (from ucimlrepo) (2024.2.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\pc world\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc world\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc world\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pc world\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pc world\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

"""
From the repository

The "goal" field refers to the presence of heart disease in the patient.
It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland
database have concentrated on simply attempting to distinguish
presence (values 1,2,3,4) from absence (value 0).
"""

print("Y \n", y.head())

# making y binary where 0 means absence and 1 means presence
y_processed = pd.DataFrame(np.where(y == 0, 0, 1), columns=['num'])
print("Processed Y",y_processed.head())
# Out:
# Y
#     num
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0
# Processed Y    num
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0

# %%
df = pd.concat([X, y_processed], axis=1)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num
# 0  0.0   6.0    0
# 1  3.0   3.0    1
# 2  2.0   7.0    1
# 3  0.0   3.0    0
# 4  0.0   3.0    0

# %% [markdown]
# ## Dataset description - **Taken from the metadata**
#
# | __Variable__ | __Description__ |
# |     :---      |       :---      |
# | __age__ | Age of the patient in years |
# | __sex__ | Gender of the patient (0 = male, 1 = female) |
# | __cp__ | Chest pain type: <br> 1: Typical angina <br> 2: Atypical angina <br> 3: Non-anginal pain <br> 4: Asymptomatic |
# | __trestbps__ | Resting blood pressure in mm Hg (on admission to the hospital)|
# | __chol__ | Serum cholesterol in mg/dl |
# | __fbs__ | Fasting blood sugar level, categorized as above 120 mg/dl (1 = true, 0 = false) |
# | __restecg__ | Resting electrocardiographic results: <br> 0: Normal <br> 1: Having ST-T wave abnormality <br> 2: Showing probable or definite left ventricular hypertrophy |
# | __thalach__ | Maximum heart rate achieved during a stress test |
# | __exang__ | Exercise-induced angina (1 = yes, 0 = no) |
# | __oldpeak__ | ST depression induced by exercise relative to rest |
# | __slope__ | Slope of the peak exercise ST segment: <br> 1: Upsloping <br> 2: Flat <br> 3: Downsloping |
# | __ca__ | Number of major vessels (0-3) colored by fluoroscopy |
# | __thal__ | Thalium stress test result: <br> 3: Normal <br> 6: Fixed defect <br> 7: Reversible defect  |
# | __target__ | Heart disease status (0 = no disease, 1 = presence of disease) |

# %% [markdown]
# ## Feature Engineering
# *Step 1* - **Exploratory Data Analysis**
#
# *Step 2* - **Handle Outliers**
#
# *Step 3* - **Handle Missing Values**
#
# *Step 4* - **Feature Scaling**

# %%
# splitting into train and test sets to avoid Data Leakage
X = df.drop('num', axis=1)
y = df['num']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Exploratory Data Analysis
# ***Steps to perform***
#
# * *Univariate analysis*
# * *Bivariate analysis*
# * *Visualize missing values*
# * *Identify outliers*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int32
# dtypes: float64(3), int32(1), int64(10)
# memory usage: 32.1 KB

# %% [markdown]
# There **303 records** in the dataset and **13 features** making shape of the dataset **(303,13)**.
#
# Missing values in **ca** = 4
#
# Missing values in **thal** = 2

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal         num
# count  301.000000  303.000000
# mean     4.734219    0.458746
# std      1.939706    0.499120
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    0.000000
# 75%      7.000000    1.000000
# max      7.000000    1.000000

# %% [markdown]
# **No categorical features**. However, some features although are numbers but have categorical nature. These features include sex, fbs, restecg, thal, slope, cp, exang and target

# %%
numeric_feat = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
categorical_feat = ['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'num', 'ca','fbs']

# %% [markdown]
# #### Univariant Analysis

# %% [markdown]
# ##### Categorical features
#
# categorical_feat = ['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'num','ca']

# %%
def plot_count(dataframe:pd.DataFrame,feat:str,x_label:str,x_ticks:list[str]=None):
  if x_ticks:
    ax = sns.countplot(x=feat, data=dataframe,palette='colorblind')
    ax.set_xticklabels(x_ticks)
  else:
    ax = sns.countplot(x=feat, data=dataframe,palette='colorblind')

  ax.set_xlabel(x_label)
  return ax

# %%
plt.figure(figsize=(13,20))
plt.subplot(5,2,1)
plot_count(df,feat='ca',x_label='Number of major blood vessels')
plt.subplot(5,2,2)
plot_count(df,feat='sex',x_label='Sex', x_ticks=['Female', 'Male'])
plt.subplot(5,2,3)
plot_count(df,feat='restecg',x_label="Resting ECG Results", x_ticks=['Normal', 'ST-T Abnormal','LVH'])
plt.subplot(5,2,4)
plot_count(df,feat='thal',x_label="Thalium Stress Test Result", x_ticks=['Normal','Fixed defect','Reversible defect'])
plt.subplot(5,2,5)
plot_count(df,feat='cp',x_label="Type of Chest Pain", x_ticks=['Typical', 'Atypical','Non-Anginal','Asymptomatic'])
plt.subplot(5,2,6)
plot_count(df,feat='exang',x_label="Exercise-induced Angina", x_ticks=['No', 'Yes'])
plt.subplot(5,2,7)
plot_count(df,feat='slope',x_label="Slope of peak exercise ST segment", x_ticks=['Upsloping','Flat','Downsloping'])
plt.subplot(5,2,8)
plot_count(df,feat='num',x_label="Heart Disease", x_ticks=['No', 'Yes'])
plt.subplot(5,2,9)
plot_count(df,feat='fbs',x_label="Fasting Blood Sugar Level above 120 mg/dl", x_ticks=['No', 'Yes'])

plt.show()

# %% [markdown]
# ###### **Inference**
#
# * Target variable appears to be **balanced** with approximately **160** *negatives* and **140** *positive* cases
# * Male patients are almost twice more than female patients so this dataset may be **male bias**
# * Most patients report **asymptomatic** chest pain
# * Most patients have **normal** thalium stress level
# * Majority patients **did not** report any exercise-related chest pain
# * Majority patients **do not** have high blood sugar
# * Majority patients during Thalium stress test showed **no major signs** of any heart disease
# * Approximately half the patients showed **normal** heart beat during resting ECG and the other half show signs of **left ventricular hypertrophy**

# %% [markdown]
# ##### Numeric features
# numeric_feat = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
def plot_histogram(dataframe:pd.DataFrame,feat:str,x_label:str):
  ax = sns.histplot(x=feat, kde=True, data=dataframe,color="purple")
  ax.set_xlabel(x_label)
  return ax

# %%
plt.figure(figsize=(13,8))
plt.subplot(2,3,1)
plot_histogram(df,"age","Age")
plt.subplot(2,3,2)
plot_histogram(df,"trestbps","Resting blood pressure in mm Hg")
plt.subplot(2,3,3)
plot_histogram(df,"chol","Cholestrol in mg/dl")
plt.subplot(2,3,4)
plot_histogram(df,"thalach","Max heart rate during stress test")
plt.subplot(2,3,5)
plot_histogram(df,"oldpeak","ST depression induced by exercise relative")

plt.show()

# %% [markdown]
# ###### **Inference**
#
# * **Age** is approximately *normally* distributed
#
# * **trestbsps**,**chol** is *right* skewed
#
# * **thalach** is *left* skewed
#
# * **oldpeak** is not normal

# %% [markdown]
# #### Bivariant Analysis
#
# Features with the target variable

# %% [markdown]
# ##### Categorical Data with target

# %%
def plot_stacked_bar(ax:plt.Axes,dataframe:pd.DataFrame,feat:str,x_label:str,x_ticks:list[str]=None):
  contingency_table = pd.crosstab(dataframe[feat], dataframe['num'])
  contingency_table_percentage = contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100
  if x_ticks:
    ax = contingency_table_percentage.plot(kind='bar', stacked=True,colormap="tab20b",ax=ax)
    ax.set_xticklabels(x_ticks,rotation=0)
  else:
    ax = contingency_table_percentage.plot(kind='bar', stacked=True,colormap="tab20b",ax=ax)
  ax.set_xlabel(x_label)
  ax.set_ylabel('Percentage')
  ax.set_title(f'Percentage Heart Disease by {x_label}')
  return ax

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(20, 20))
axes = axes.flatten()


plot_stacked_bar(axes[0], df, feat='sex', x_label="Sex", x_ticks=['Female', 'Male'])
plot_stacked_bar(axes[1], df, feat='restecg', x_label='Resting ECG', x_ticks=['Normal', 'ST-T Abnormality', 'LVH'])
plot_stacked_bar(axes[2], df, feat='thal', x_label='Thalium stress results', x_ticks=['Normal', 'Fixed defect', 'Reversible defect'])
plot_stacked_bar(axes[3], df, feat='cp', x_label="Chest Pain", x_ticks=['Typical angina', 'Atypical angina', 'Non-anginal pain', 'Asymptomatic'])
plot_stacked_bar(axes[4], df, feat='exang', x_label='Exercise-induced Angina', x_ticks=['No', 'Yes'])
plot_stacked_bar(axes[5], df, feat='ca', x_label='No. of major blood vessels')
plot_stacked_bar(axes[6], df, feat='slope', x_label='Slope of ST segment', x_ticks=['Upsloping', 'Flat', 'Downsloping'])
plot_stacked_bar(axes[7], df, feat='fbs', x_label='Fasting blood sugar level', x_ticks=['No', 'Yes'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### **Inference**
#
# * Most *female* patients **did not** have heart disease while almost half the *male* patients **have** heart disease
# * Patients that show **abnormal** *ST and T* waves are **more likely** to have heart disease
# * Patients with **normal** *thalium stress test* results are likely to be **safe** from disease
# * Patients that report **asymptomatic** *chest pain* are **more likely** to have heart disease
# *  Patients that report **exercise-related** *angina* are **more likely** to have heart disease
# * Blood sugar seems to have **no affect** to predict whether a patient  has heart disease or not.

# %% [markdown]
# ##### Numeric data with target

# %%
def plot_boxplot(ax:plt.axis, dataframe:pd.DataFrame,feat:str,x_label:str):
  ax = sns.boxplot(y=feat, x='num', data=dataframe,ax=ax,palette="Set2")
  ax.set_ylabel(x_label)
  ax.set_xlabel('Heart Disease')
  ax.set_title(f'Box Plot of Target by {x_label}')
  return ax

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10, 10))
axes = axes.flatten()

plot_boxplot(axes[0], df, feat='age', x_label="Age")
plot_boxplot(axes[1], df, feat='trestbps', x_label='Resting Blood Pressure')
plot_boxplot(axes[2], df, feat='chol', x_label='Cholestrol')
plot_boxplot(axes[3], df, feat='thalach', x_label="Maximum Heart Rate")
plot_boxplot(axes[4], df, feat='oldpeak', x_label='Exercise induced ST depression')
axes[5].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### **Inference**
#
# * *Several **outliers** present in the dataset which needs to be handled*
# * **Older** patients are at **higher risk** of Heart Disease
# * Patients that showed **higher maximun heart rate** during *stress test* tend to be **safe** from heart disease
# * Patients that show a **greater** *ST segment depression* are at a **higher risk** of disease

# %% [markdown]
# ### Dealing with Outliers
# There are two techniques to identify outliers.
# * Z-score method
# * IQR method

# %%
numeric_feat
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %% [markdown]
# > If the skewness is **between** *-0.5* and *0.5*, the data are **fairly symmetrical**
#
# > If the skewness is **between** *-1* and *—0.5* or between *0.5* and *1*, the data are **moderately skewed**
#
# > If the skewness is **less** than *-1* or **greater** than *1*, the data are **highly skewed**

# %%
for feat in numeric_feat:
  print(f"{feat} skewness = {X_train[feat].skew()}")
# Out:
# age skewness = -0.06885075730219788
# trestbps skewness = 0.6962939139840222
# chol skewness = 0.8322778497077913
# thalach skewness = -0.5447412987907116
# oldpeak skewness = 1.4179323894258087

# %% [markdown]
# Data has moderate skewness as calculated above and seen graphically aswell. Therefore, **IQR method** will be used to handle the outliers.
#
# Since **Z-score method** assumes a normal distribution and is sensitive to misidentify points as outliers.
#
# On the other hand, the **IQR method** is more robust and less affected by the skewness.

# %%
def check_outliers(df:pd.DataFrame,feat_list:list[str]) -> pd.Series:
  Q1 = df[feat_list].quantile(0.25)
  Q3 = df[feat_list].quantile(0.75)
  IQR = Q3 - Q1
  outliers_count_specified = ((df[feat_list] < (Q1 - 1.5 * IQR)) | (df[feat_list] > (Q3 + 1.5 * IQR))).sum()
  return outliers_count_specified

# %%
# check outliers using IQR method
check_outliers(X_train,numeric_feat)
# Out:
# age         0
# trestbps    8
# chol        4
# thalach     2
# oldpeak     4
# dtype: int64

# %%
# check outliers using IQR method
check_outliers(X_test,numeric_feat)
# Out:
# age         1
# trestbps    1
# chol        1
# thalach     0
# oldpeak     1
# dtype: int64

# %% [markdown]
# #### How to handle the Outliers
# There are two techniques.
# * Trimming -> remove them
# * Capping -> apply upper and lower limits

# %%
def show_outlier_data(dataframe:pd.DataFrame,feat:str) -> pd.DataFrame:
  Q1 = dataframe[feat].quantile(0.25)
  Q3 = dataframe[feat].quantile(0.75)
  IQR = Q3 - Q1
  return dataframe[(dataframe[feat] < (Q1 - 1.5 * IQR)) | (dataframe[feat] > (Q3 + 1.5 * IQR))]

# %%
# display the trestbps outlier rows
show_outlier_data(X_train,"trestbps")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 126   56    0   4       200   288    1        2      133      1      4.0
# 183   59    1   1       178   270    0        2      145      0      4.2
# 172   59    0   4       174   249    0        0      143      1      0.0
# 83    68    1   3       180   274    1        2      150      1      1.6
# 213   66    0   4       178   228    1        0      165      1      1.0
# 14    52    1   3       172   199    1        0      162      0      0.5
# 201   64    0   4       180   325    0        0      154      1      0.0
# 188   54    1   2       192   283    0        2      195      0      0.0
#
#      slope   ca  thal
# 126      3  2.0   7.0
# 183      3  0.0   7.0
# 172      2  0.0   3.0
# 83       2  0.0   7.0
# 213      2  2.0   7.0
# 14       1  0.0   7.0
# 201      1  0.0   3.0
# 188      1  1.0   7.0

# %% [markdown]
# **trestbps** is the Resting Blood Pressure recorded when a patient is admitted to the hospital. These readings are a case of hypertension which may be due to some heart diseases so cannot be erroneous. Hence cannot be removed so it will be **capped**

# %%
# display the cholestrol outlier rows
show_outlier_data(X_train,"chol")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 173   62    0   4       140   394    0        2      157      0      1.2
# 181   56    0   4       134   409    0        2      150      1      1.9
# 48    65    0   3       140   417    1        2      157      0      0.8
# 121   63    0   4       150   407    0        2      154      0      4.0
#
#      slope   ca  thal
# 173      2  0.0   3.0
# 181      2  2.0   7.0
# 48       1  1.0   3.0
# 121      2  3.0   7.0

# %% [markdown]
# **chol** is the Cholestrol recorded in mg/dl. These readings are a case of patients with high cholestrol. These readings are possible so cannot be erroneous. Hence cannot be removed so it will be **capped**

# %%
# display the max heart rate achieved outlier rows
show_outlier_data(X_train,"thalach")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 296   59    1   4       164   176    1        2       90      0      1.0
# 245   67    1   4       120   237    0        0       71      0      1.0
#
#      slope   ca  thal
# 296      2  2.0   6.0
# 245      2  0.0   3.0

# %% [markdown]
# **thalach** is the maximum heart rate acheived during stress test. These readings are possible so cannot be erroneous. Hence cannot be removed so it will be **capped**

# %%
# display the st depression outlier rows
show_outlier_data(X_train,"oldpeak")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 183   59    1   1       178   270    0        2      145      0      4.2
# 123   55    1   4       140   217    0        0      111      1      5.6
# 91    62    0   4       160   164    0        2      145      0      6.2
# 191   51    1   4       140   298    0        0      122      1      4.2
#
#      slope   ca  thal
# 183      3  0.0   7.0
# 123      3  0.0   7.0
# 91       3  3.0   7.0
# 191      2  3.0   7.0

# %% [markdown]
# **oldpeak** is the ST segment depression rate. These readings are possible so cannot be erroneous. Hence cannot be removed so it will be **capped**

# %%
def cap_outliers(df:pd.DataFrame,feat_list:list[str]) -> pd.DataFrame:
  data = df.copy()
  IQR = data[feat_list].quantile(0.75) - data[feat_list].quantile(0.25)
  lower_limit = data[feat_list].quantile(0.25) - (1.5 * (IQR))
  upper_limit = data[feat_list].quantile(0.75) + (1.5 * (IQR))
  data[feat_list] = np.where(
      data[feat_list] < lower_limit,
      lower_limit,
      np.where(data[feat_list] > upper_limit,
              upper_limit,
              data[feat_list]
              )
      )
  return data

# %%
x_train_cap = cap_outliers(X_train,numeric_feat)
x_test_cap = cap_outliers(X_test,numeric_feat)

# %%
# check outliers using IQR method
check_outliers(x_train_cap,numeric_feat)
# Out:
# age         0
# trestbps    0
# chol        0
# thalach     0
# oldpeak     0
# dtype: int64

# %%
# check outliers using IQR method
check_outliers(x_test_cap,numeric_feat)
# Out:
# age         0
# trestbps    0
# chol        0
# thalach     0
# oldpeak     0
# dtype: int64

# %% [markdown]
# The outlier have been capped as the result shows

# %%
for feat in numeric_feat:
  print(f"{feat} skewness = {x_train_cap[feat].skew()}")
# Out:
# age skewness = -0.06885075730219788
# trestbps skewness = 0.3278639613104055
# chol skewness = 0.456882260396959
# thalach skewness = -0.4107866564620405
# oldpeak skewness = 1.09747860410658

# %% [markdown]
# It is also to be noted that the data has become more gaussian after capping

# %%
plt.figure(figsize=(13,15))

plt.subplot(4,2,1)
plot_histogram(X_train,"trestbps","Resting blood pressure in mm Hg")
plt.title('Before Capping')
plt.subplot(4,2,2)
plot_histogram(x_train_cap,"trestbps","Resting blood pressure in mm Hg")
plt.title('After Capping')

plt.subplot(4,2,3)
plot_histogram(X_train,"chol","Cholestrol in mg/dl")
plt.subplot(4,2,4)
plot_histogram(x_train_cap,"chol","Cholestrol in mg/dl")

plt.subplot(4,2,5)
plot_histogram(X_train,"thalach","Max heart rate during stress test")
plt.subplot(4,2,6)
plot_histogram(x_train_cap,"thalach","Max heart rate during stress test")


plt.subplot(4,2,7)
plot_histogram(X_train,"oldpeak","ST depression induced by exercise relative")
plt.subplot(4,2,8)
plot_histogram(x_train_cap,"oldpeak","ST depression induced by exercise relative")





plt.show()

# %% [markdown]
# ### Handling Missing Values

# %%
# creating copies so future errors easier to identify and solve
x_train2 = x_train_cap.copy()
x_test2 = x_test_cap.copy()

# %%
x_train2.isnull().mean()*100 # percentage of values missing
# Out:
# age         0.000000
# sex         0.000000
# cp          0.000000
# trestbps    0.000000
# chol        0.000000
# fbs         0.000000
# restecg     0.000000
# thalach     0.000000
# exang       0.000000
# oldpeak     0.000000
# slope       0.000000
# ca          0.985222
# thal        0.985222
# dtype: float64

# %% [markdown]
# * Less than **1%** values missing from both features
# * Both missing features are **categorical**

# %%
print("Total number of records in train set are: ", x_train2.shape[0])
# Out:
# Total number of records in train set are:  203

# %% [markdown]
# **Small dataset** so cannot remove missing values
#
# **Alternates**
#
#
# *   Replace with mode
# *   Use KNN imputation to fill missing values

# %%
x_train2[x_train2['ca'].isnull()]
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 166  52.0    1   3     138.0  223.0    0        0    169.0      0      0.0
# 302  38.0    1   3     138.0  175.0    0        0    173.0      0      0.0
#
#      slope  ca  thal
# 166      1 NaN   3.0
# 302      1 NaN   3.0

# %%
x_train2[x_train2['thal'].isnull()]
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 266  52.0    1   4     128.0  204.0    1        0    156.0      1      1.0
# 87   53.0    0   3     128.0  216.0    0        2    115.0      0      0.0
#
#      slope   ca  thal
# 266      2  0.0   NaN
# 87       1  0.0   NaN

# %% [markdown]
# #### Impute missing values with the mode

# %%
from sklearn.impute import SimpleImputer

si = SimpleImputer(strategy='most_frequent')
si.set_output(transform='pandas')
x_train2_trf = si.fit_transform(x_train2)
x_test2_trf = si.transform(x_test2)

# %%
# thal imputed records
print("Mode of x_train_cap['thal'] = ",x_train_cap['thal'].mode()[0])
x_train2_trf[(x_train2_trf.index == 87)| (x_train2_trf.index == 266)]
# Out:
# Mode of x_train_cap['thal'] =  3.0
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 266  52.0  1.0  4.0     128.0  204.0  1.0      0.0    156.0    1.0      1.0
# 87   53.0  0.0  3.0     128.0  216.0  0.0      2.0    115.0    0.0      0.0
#
#      slope   ca  thal
# 266    2.0  0.0   3.0
# 87     1.0  0.0   3.0

# %%
# ca imputed records
print("Mode of x_train_cap['ca'] = ",x_train_cap['ca'].mode()[0])
x_train2_trf[(x_train2_trf.index == 166)| (x_train2_trf.index == 302)]
# Out:
# Mode of x_train_cap['ca'] =  0.0
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 166  52.0  1.0  3.0     138.0  223.0  0.0      0.0    169.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal
# 166    1.0  0.0   3.0
# 302    1.0  0.0   3.0

# %% [markdown]
# #### Impute missing values using KNN
# ---
# *KNNImputer* uses **nan_euclidean_distances** and replaces missing value with the average of the KNN
#
#  Since this is classification imputation setting **n_neighbors=1** so it only considers the closest neighbor. The value returned is the value of that neighbor. We **do not** get averages.

# %%
from sklearn.impute import KNNImputer


knni = KNNImputer(n_neighbors=1)
knni.set_output(transform='pandas')
x_train2_trf2 = knni.fit_transform(x_train2)
x_test2_trf2 = knni.transform(x_test2)

# %%
# thal imputed records
x_train2_trf2[(x_train2_trf2.index == 87)| (x_train2_trf2.index == 266)]
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 266  52.0  1.0  4.0     128.0  204.0  1.0      0.0    156.0    1.0      1.0
# 87   53.0  0.0  3.0     128.0  216.0  0.0      2.0    115.0    0.0      0.0
#
#      slope   ca  thal
# 266    2.0  0.0   3.0
# 87     1.0  0.0   7.0

# %%
# ca imputed records
x_train2_trf2[(x_train2_trf2.index == 166)| (x_train2_trf2.index == 302)]
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 166  52.0  1.0  3.0     138.0  223.0  0.0      0.0    169.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal
# 166    1.0  0.0   3.0
# 302    1.0  0.0   3.0

# %% [markdown]
# ### Feature Scaling

# %%
# remove it as num is target variable not part of train or test set
cat = categorical_feat.copy()
cat.remove('num')
cat
# Out:
# ['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'ca', 'fbs']

# %% [markdown]
# #### **Two Approaches**
#
# 1.   **Standardization** - *StandardScaler*
# 2.   **Normalization** - *MinMaxScaler*

# %% [markdown]
# #### **Standardization**

# %%
from sklearn.preprocessing import StandardScaler

# standardize the data imputed with mode
ss1 = StandardScaler()
ss1.set_output(transform='pandas')
x_train3_mode = ss1.fit_transform(x_train2_trf[numeric_feat])
x_test3_mode = ss1.transform(x_test2_trf[numeric_feat])

# standard scaling + mode imputation
x_train3_std_mode = pd.concat([x_train2_trf[cat],x_train3_mode],axis=1)
x_test3_std_mode = pd.concat([x_test2_trf[cat],x_test3_mode],axis=1)

# %%
print("Before\n",x_train2_trf.head(2))
print("After\n",x_train3_std_mode.head(2))
# Out:
# Before
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 37  57.0  1.0  4.0     150.0  276.0  0.0      2.0    112.0    1.0      0.6
# 16  48.0  1.0  2.0     110.0  229.0  0.0      0.0    168.0    0.0      1.0
#
#     slope   ca  thal
# 37    2.0  1.0   6.0
# 16    3.0  0.0   7.0
# After
#      sex  restecg  thal  slope   cp  exang   ca  fbs       age  trestbps  \
# 37  1.0      2.0   6.0    2.0  4.0    1.0  1.0  0.0  0.281915  1.047231
# 16  1.0      0.0   7.0    3.0  2.0    0.0  0.0  0.0 -0.697283 -1.258495
#
#         chol   thalach   oldpeak
# 37  0.703355 -1.826463 -0.346171
# 16 -0.353450  0.791356  0.003880

# %%
from sklearn.preprocessing import StandardScaler

ss2 = StandardScaler()
ss2.set_output(transform='pandas')
x_train3_knn = ss2.fit_transform(x_train2_trf2[numeric_feat])
x_test3_knn = ss2.transform(x_test2_trf2[numeric_feat])

# standard scaling + knn imputation
x_train3_std_knn = pd.concat([x_train2_trf2[cat],x_train3_knn],axis=1)
x_test3_std_knn = pd.concat([x_test2_trf2[cat],x_test3_knn],axis=1)

# %%
print("Before\n",x_train2_trf2.head(2))
print("After\n",x_train3_std_knn.head(2))
# Out:
# Before
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 37  57.0  1.0  4.0     150.0  276.0  0.0      2.0    112.0    1.0      0.6
# 16  48.0  1.0  2.0     110.0  229.0  0.0      0.0    168.0    0.0      1.0
#
#     slope   ca  thal
# 37    2.0  1.0   6.0
# 16    3.0  0.0   7.0
# After
#      sex  restecg  thal  slope   cp  exang   ca  fbs       age  trestbps  \
# 37  1.0      2.0   6.0    2.0  4.0    1.0  1.0  0.0  0.281915  1.047231
# 16  1.0      0.0   7.0    3.0  2.0    0.0  0.0  0.0 -0.697283 -1.258495
#
#         chol   thalach   oldpeak
# 37  0.703355 -1.826463 -0.346171
# 16 -0.353450  0.791356  0.003880

# %% [markdown]
# #### **Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler

# standardize the data imputed with mode
mms1 = MinMaxScaler()
mms1.set_output(transform='pandas')
x_train4_mode = mms1.fit_transform(x_train2_trf[numeric_feat])
x_test4_mode = mms1.transform(x_test2_trf[numeric_feat])

# min max scaling + mode imputation
x_train4_std_mode = pd.concat([x_train2_trf[cat],x_train4_mode],axis=1)
x_test4_std_mode = pd.concat([x_test2_trf[cat],x_test4_mode],axis=1)

# %%
print("Before\n",x_train2_trf.head(2))
print("After\n",x_train4_std_mode.head(2))
# Out:
# Before
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 37  57.0  1.0  4.0     150.0  276.0  0.0      2.0    112.0    1.0      0.6
# 16  48.0  1.0  2.0     110.0  229.0  0.0      0.0    168.0    0.0      1.0
#
#     slope   ca  thal
# 37    2.0  1.0   6.0
# 16    3.0  0.0   7.0
# After
#      sex  restecg  thal  slope   cp  exang   ca  fbs       age  trestbps  \
# 37  1.0      2.0   6.0    2.0  4.0    1.0  1.0  0.0  0.534884  0.736842
# 16  1.0      0.0   7.0    3.0  2.0    0.0  0.0  0.0  0.325581  0.210526
#
#         chol   thalach  oldpeak
# 37  0.596244  0.180247     0.15
# 16  0.375587  0.733333     0.25

# %%
from sklearn.preprocessing import MinMaxScaler

# standardize the data imputed with mode
mms1 = MinMaxScaler()
mms1.set_output(transform='pandas')
x_train4_knn = mms1.fit_transform(x_train2_trf2[numeric_feat])
x_test4_knn = mms1.transform(x_test2_trf2[numeric_feat])

# min max scaling + knn imputation
x_train4_std_knn = pd.concat([x_train2_trf2[cat],x_train4_knn],axis=1)
x_test4_std_knn = pd.concat([x_test2_trf2[cat],x_test4_knn],axis=1)

# %%
print("Before\n",x_train2_trf.head(2))
print("After\n",x_train4_std_knn.head(2))
# Out:
# Before
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 37  57.0  1.0  4.0     150.0  276.0  0.0      2.0    112.0    1.0      0.6
# 16  48.0  1.0  2.0     110.0  229.0  0.0      0.0    168.0    0.0      1.0
#
#     slope   ca  thal
# 37    2.0  1.0   6.0
# 16    3.0  0.0   7.0
# After
#      sex  restecg  thal  slope   cp  exang   ca  fbs       age  trestbps  \
# 37  1.0      2.0   6.0    2.0  4.0    1.0  1.0  0.0  0.534884  0.736842
# 16  1.0      0.0   7.0    3.0  2.0    0.0  0.0  0.0  0.325581  0.210526
#
#         chol   thalach  oldpeak
# 37  0.596244  0.180247     0.15
# 16  0.375587  0.733333     0.25

# %% [markdown]
# ## Feature Selection
#
# List of train sets
# * **x_train3_std_mode** - standard scaling + mode imputation
# * **x_train3_std_knn** - standard scaling + knn imputation
# * **x_train4_std_mode** - min max scaling + mode imputation
# * **x_train4_std_knn** - min max scaling + knn imputation

# %% [markdown]
# ### Pearson Correlation Matrix
#
#
# > **Goal**: Drop features with high correlation (**assuming threshold of 70%**) between them as they similar information
#
#
# A value between **-1 and 1**, where **0 is no correlation**, **1 is total positive correlation**, and **-1 is total negative correlation**.
#
# A correlation **value of 0.7 between two variables** would indicate that a **significant and positive relationship** exists between the two.
#
# A positive correlation signifies that if variable A goes up, then B will also go up, whereas if the value of the correlation is negative, then if A increases, B decreases.

# %%
def get_correlation(df:pd.DataFrame,threshold:float) -> set:
  """
  Purpose: Search for features with a strong positive or strong negative correlation

  Working: Iterate over the correlation and where absolute value is greater than
  threshold add the feature to the set

  """
  col_corr = set()
  corr_matrix = df.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i, j]) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(x_train3_std_mode.corr(), vmin=-1, vmax=1, annot=True, cmap="PiYG")
heatmap.set_title('Correlation Heatmap on x_train3_std_mode', fontdict={'fontsize':12}, pad=12);
get_correlation(x_train3_std_mode,0.7)
# Out:
# set()

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(x_train3_std_knn.corr(), vmin=-1, vmax=1, annot=True, cmap="PiYG")
heatmap.set_title('Correlation Heatmap on x_train3_std_knn', fontdict={'fontsize':12}, pad=12);
get_correlation(x_train3_std_knn,0.7)
# Out:
# set()

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(x_train4_std_mode.corr(), vmin=-1, vmax=1, annot=True, cmap="PiYG")
heatmap.set_title('Correlation Heatmap on x_train4_std_mode', fontdict={'fontsize':12}, pad=12);
get_correlation(x_train4_std_mode,0.7)
# Out:
# set()

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(x_train4_std_knn.corr(), vmin=-1, vmax=1, annot=True, cmap="PiYG")
heatmap.set_title('Correlation Heatmap on x_train4_std_knn', fontdict={'fontsize':12}, pad=12);
get_correlation(x_train4_std_knn,0.7)
# Out:
# set()

# %% [markdown]
# #### **Inference**
# There is no strong positive or negative relation between the features. Therefore, all features carry unique information

# %% [markdown]
# ### Mutual Information
#
# > **Goal:** Select the top 10 **(k=10)** most important features from each dataset
#
# Estimate mutual information for a discrete target variable.
#
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is **equal to zero** if and only if two random variables are **independent**, and **higher values mean higher dependency**.
#
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances

# %% [markdown]
# **The formula for mutual information (MI) is:**
#
# > *MI(D, A) = H(D) - H(D|A)*
#
# **Where:**
#
# **MI(D, A) is the mutual information of feature A in dataset D**
#
# **H(D) is the entropy of the class distribution in dataset D**
#
# **H(D|A) is the conditional entropy of the class distribution in dataset D given feature A**

# %%
# First 8 columns features are discrete
x_train3_std_mode.columns[:8] == cat
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
def custom_caller(X,y):
  return mutual_info_classif(X, y, discrete_features=[0,1,2,3,4,5,6,7])

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest


s_10_b = SelectKBest(score_func=custom_caller,k=10)
s_10_b.set_output(transform='pandas')

new_x_train3_std_mode = s_10_b.fit_transform(x_train3_std_mode,y_train)
new_x_test3_std_mode = s_10_b.transform(x_test3_std_mode)
new_x_train3_std_mode.columns
# Out:
# Index(['sex', 'thal', 'slope', 'cp', 'exang', 'ca', 'age', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest


s_10_b = SelectKBest(score_func=custom_caller,k=10)
s_10_b.set_output(transform='pandas')

new_x_train3_std_knn = s_10_b.fit_transform(x_train3_std_knn,y_train)
new_x_test3_std_knn = s_10_b.transform(x_test3_std_knn)
new_x_train3_std_knn.columns
# Out:
# Index(['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'ca', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest


s_10_b = SelectKBest(score_func=custom_caller,k=10)
s_10_b.set_output(transform='pandas')

new_x_train4_std_mode = s_10_b.fit_transform(x_train4_std_mode,y_train)
new_x_test4_std_mode = s_10_b.transform(x_test4_std_mode)
new_x_train4_std_mode.columns
# Out:
# Index(['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'ca', 'chol',
#        'thalach', 'oldpeak'],
#       dtype='object')

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest


s_10_b = SelectKBest(score_func=custom_caller,k=10)
s_10_b.set_output(transform='pandas')

new_x_train4_std_knn = s_10_b.fit_transform(x_train4_std_knn,y_train)
new_x_test4_std_knn = s_10_b.transform(x_test4_std_knn)
new_x_train4_std_knn.columns
# Out:
# Index(['sex', 'thal', 'slope', 'cp', 'exang', 'ca', 'age', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')

# %% [markdown]
# ### Chi Square Test For Categorical Features
#
# > **Goal**: Obtain the top 3 (**k=5**) highest scoring categorical features in the dataset
#
# Compute chi-squared stats between each non-negative feature and class.
#
# This score can be used to select the **n_features** features with the highest values for the test chi-squared statistic from X, which must contain only non-negative features such as booleans or frequencies, relative to the classes.
#
# Recall that the chi-square test measures dependence between **stochastic** variables, so using this function “weeds out” the features that are the most likely to be independent of class and therefore irrelevant for classification.

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

print(new_x_train3_std_mode.columns)

# first 7 columns are categorical features
c = new_x_train3_std_mode.columns[:7]
n = new_x_train3_std_mode.columns[7:]

s_3_b = SelectKBest(score_func=chi2,k=5)
s_3_b.set_output(transform='pandas')

_ = s_3_b.fit_transform(new_x_train3_std_mode[c],y_train)
x_train_5a = pd.concat([x_train3_std_mode[n],_],axis=1)
x_train_5a.columns
# Out:
# Index(['sex', 'thal', 'slope', 'cp', 'exang', 'ca', 'age', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[145], line 13
#      10 s_3_b = SelectKBest(score_func=chi2,k=5)
#      11 s_3_b.set_output(transform='pandas')
# ---> 13 _ = s_3_b.fit_transform(new_x_train3_std_mode[c],y_train)
#      14 x_train_5a = pd.concat([x_train3_std_mode[n],_],axis=1)
#      15 x_train_5a.columns
#
# File c:\Users\pc world\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\pc world\anaconda3\Lib\site-packages\sklearn\base.py:881, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     878     return self.fit(X, **fit_params).transform(X)
#     879 else:
#     880     # fit method of arity 2 (supervised transformation)
# --> 881     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\pc world\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:472, in _BaseFilter.fit(self, X, y)
#     467 X, y = self._validate_data(
#     468     X, y, accept_sparse=["csr", "csc"], multi_output=True
#     469 )
#     471 self._check_params(X, y)
# --> 472 score_func_ret = self.score_func(X, y)
#     473 if isinstance(score_func_ret, (list, tuple)):
#     474     self.scores_, self.pvalues_ = score_func_ret
#
# File c:\Users\pc world\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:217, in chi2(X, y)
#     215 X = check_array(X, accept_sparse="csr", dtype=(np.float64, np.float32))
#     216 if np.any((X.data if issparse(X) else X) < 0):
# --> 217     raise ValueError("Input X must be non-negative.")
#     219 # Use a sparse representation for Y by default to reduce memory usage when
#     220 # y has many unique classes.
#     221 Y = LabelBinarizer(sparse_output=True).fit_transform(y)
#
# ValueError: Input X must be non-negative.

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

print(new_x_train3_std_knn.columns)

# first 7 columns are categorical features
c = new_x_train3_std_knn.columns[:7]
n = new_x_train3_std_knn.columns[7:]

s_3_b = SelectKBest(score_func=chi2,k=5)
s_3_b.set_output(transform='pandas')

_ = s_3_b.fit_transform(new_x_train3_std_knn[c],y_train)
x_train_5b = pd.concat([x_train3_std_knn[n],_],axis=1)
x_train_5b.columns
# Out:
# Index(['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'ca', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')
# Index(['trestbps', 'thalach', 'oldpeak', 'sex', 'thal', 'cp', 'exang', 'ca'], dtype='object')

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

print(new_x_train4_std_mode.columns)

# first 6 columns are categorical features
c = new_x_train4_std_mode.columns[:6]
n = new_x_train4_std_mode.columns[6:]

s_3_b = SelectKBest(score_func=chi2,k=5)
s_3_b.set_output(transform='pandas')

_ = s_3_b.fit_transform(new_x_train4_std_mode[c],y_train)
x_train_6a = pd.concat([x_train4_std_mode[n],_],axis=1)
x_train_6a.columns
# Out:
# Index(['sex', 'restecg', 'thal', 'slope', 'cp', 'exang', 'ca', 'chol',
#        'thalach', 'oldpeak'],
#       dtype='object')
# Index(['ca', 'chol', 'thalach', 'oldpeak', 'sex', 'restecg', 'thal', 'cp',
#        'exang'],
#       dtype='object')

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

print(new_x_train4_std_knn.columns)

# first 7 columns are categorical features
c = new_x_train4_std_knn.columns[:7]
n = new_x_train4_std_knn.columns[7:]

s_3_b = SelectKBest(score_func=chi2,k=5)
s_3_b.set_output(transform='pandas')

_ = s_3_b.fit_transform(new_x_train4_std_knn[c],y_train)
x_train_6b = pd.concat([new_x_train4_std_knn[n],_],axis=1)
x_train_6b.columns
# Out:
# Index(['sex', 'thal', 'slope', 'cp', 'exang', 'ca', 'age', 'trestbps',
#        'thalach', 'oldpeak'],
#       dtype='object')
# Index(['trestbps', 'thalach', 'oldpeak', 'sex', 'thal', 'cp', 'exang', 'ca'], dtype='object')

# %% [markdown]
# ### **Final Datasets**
# After Pearson Correlation - 13 Features
# * **x_train3_std_mode** - standard scaling + mode imputation
# * **x_train3_std_knn** - standard scaling + knn imputation
# * **x_train4_std_mode** - min max scaling + mode imputation
# * **x_train4_std_knn** - min max scaling + knn imputation
#
# After Mutual Information Gain -  10 Features
# * **new_x_train3_std_mode**
# * **new_x_train3_std_knn**
# * **new_x_train4_std_mode**
# * **new_x_train4_std_knn**
#
# After Chi Square Test -  8 Features
# * **x_train_5a**
# * **x_train_5b**
# * **x_train_6a**
# * **x_train_6b**

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# MODEL TRAINING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
import warnings

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.svm import SVR, SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

# Define models
regression_models = {
    "Linear Regression": LinearRegression(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Support Vector Regressor": SVR(),

}

classification_models = {
    "Logistic Regression": LogisticRegression(),
    "K-Neighbors Classifier": KNeighborsClassifier(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "Support Vector Classifier": SVC(),
    "Naive Bayes Classifier": GaussianNB(),
}


# Prepare dataset mappings (add your classification datasets here)
datasets = {
    "x_train3_std_mode": (x_train3_std_mode, y_train),
    "x_train3_std_knn": (x_train3_std_knn, y_train),
    "x_train4_std_mode": (x_train4_std_mode, y_train),
    "x_train4_std_knn": (x_train4_std_knn, y_train),
    "new_x_train3_std_mode": (new_x_train3_std_mode, y_train),
    "new_x_train3_std_knn": (new_x_train3_std_knn, y_train),
    "new_x_train4_std_mode": (new_x_train4_std_mode, y_train),
    "new_x_train4_std_knn": (new_x_train4_std_knn, y_train),
    "x_train_5a": (x_train_5a, y_train),
    "x_train_5b": (x_train_5b, y_train),
    "x_train_6a": (x_train_6a, y_train),
    "x_train_6b": (x_train_6b, y_train),
    # Add your classification datasets here if needed
}

for dataset_name, (X_train, y_train) in datasets.items():
    print(f"Training models on dataset: {dataset_name}")

    print("Training regression models...")
    for model_name, model in regression_models.items():
        model.fit(X_train, y_train)  # Train model
        print(f"{model_name} trained on {dataset_name}")

    print("Training classification models...")
    for model_name, model in classification_models.items():
        model.fit(X_train, y_train)  # Train model
        print(f"{model_name} trained on {dataset_name}")

print("Training completed.")
# Out:
# Training models on dataset: x_train3_std_mode
# Training regression models...
# Linear Regression trained on x_train3_std_mode
# K-Neighbors Regressor trained on x_train3_std_mode
# Decision Tree Regressor trained on x_train3_std_mode
# Support Vector Regressor trained on x_train3_std_mode
# Training classification models...
# Logistic Regression trained on x_train3_std_mode
# K-Neighbors Classifier trained on x_train3_std_mode
# Decision Tree Classifier trained on x_train3_std_mode
# Support Vector Classifier trained on x_train3_std_mode
# Naive Bayes Classifier trained on x_train3_std_mode
# Training models on dataset: x_train3_std_knn
# Training regression models...
# Linear Regression trained on x_train3_std_knn
# K-Neighbors Regressor trained on x_train3_std_knn
# Decision Tree Regressor trained on x_train3_std_knn
# Support Vector Regressor trained on x_train3_std_knn
# Training classification models...
# Logistic Regression trained on x_train3_std_knn
# K-Neighbors Classifier trained on x_train3_std_knn
# Decision Tree Classifier trained on x_train3_std_knn
# Support Vector Classifier trained on x_train3_std_knn
# Naive Bayes Classifier trained on x_train3_std_knn
# Training models on dataset: x_train4_std_mode
# Training regression models...
# Linear Regression trained on x_train4_std_mode
# K-Neighbors Regressor trained on x_train4_std_mode
# Decision Tree Regressor trained on x_train4_std_mode
# Support Vector Regressor trained on x_train4_std_mode
# Training classification models...
# Logistic Regression trained on x_train4_std_mode
# K-Neighbors Classifier trained on x_train4_std_mode
# Decision Tree Classifier trained on x_train4_std_mode
# Support Vector Classifier trained on x_train4_std_mode
# Naive Bayes Classifier trained on x_train4_std_mode
# Training models on dataset: x_train4_std_knn
# Training regression models...
# Linear Regression trained on x_train4_std_knn
# K-Neighbors Regressor trained on x_train4_std_knn
# Decision Tree Regressor trained on x_train4_std_knn
# Support Vector Regressor trained on x_train4_std_knn
# Training classification models...
# Logistic Regression trained on x_train4_std_knn
# K-Neighbors Classifier trained on x_train4_std_knn
# Decision Tree Classifier trained on x_train4_std_knn
# Support Vector Classifier trained on x_train4_std_knn
# Naive Bayes Classifier trained on x_train4_std_knn
# Training models on dataset: new_x_train3_std_mode
# Training regression models...
# Linear Regression trained on new_x_train3_std_mode
# K-Neighbors Regressor trained on new_x_train3_std_mode
# Decision Tree Regressor trained on new_x_train3_std_mode
# Support Vector Regressor trained on new_x_train3_std_mode
# Training classification models...
# Logistic Regression trained on new_x_train3_std_mode
# K-Neighbors Classifier trained on new_x_train3_std_mode
# Decision Tree Classifier trained on new_x_train3_std_mode
# Support Vector Classifier trained on new_x_train3_std_mode
# Naive Bayes Classifier trained on new_x_train3_std_mode
# Training models on dataset: new_x_train3_std_knn
# Training regression models...
# Linear Regression trained on new_x_train3_std_knn
# K-Neighbors Regressor trained on new_x_train3_std_knn
# Decision Tree Regressor trained on new_x_train3_std_knn
# Support Vector Regressor trained on new_x_train3_std_knn
# Training classification models...
# Logistic Regression trained on new_x_train3_std_knn
# K-Neighbors Classifier trained on new_x_train3_std_knn
# Decision Tree Classifier trained on new_x_train3_std_knn
# Support Vector Classifier trained on new_x_train3_std_knn
# Naive Bayes Classifier trained on new_x_train3_std_knn
# Training models on dataset: new_x_train4_std_mode
# Training regression models...
# Linear Regression trained on new_x_train4_std_mode
# K-Neighbors Regressor trained on new_x_train4_std_mode
# Decision Tree Regressor trained on new_x_train4_std_mode
# Support Vector Regressor trained on new_x_train4_std_mode
# Training classification models...
# Logistic Regression trained on new_x_train4_std_mode
# K-Neighbors Classifier trained on new_x_train4_std_mode
# Decision Tree Classifier trained on new_x_train4_std_mode
# Support Vector Classifier trained on new_x_train4_std_mode
# Naive Bayes Classifier trained on new_x_train4_std_mode
# Training models on dataset: new_x_train4_std_knn
# Training regression models...
# Linear Regression trained on new_x_train4_std_knn
# K-Neighbors Regressor trained on new_x_train4_std_knn
# Decision Tree Regressor trained on new_x_train4_std_knn
# Support Vector Regressor trained on new_x_train4_std_knn
# Training classification models...
# Logistic Regression trained on new_x_train4_std_knn
# K-Neighbors Classifier trained on new_x_train4_std_knn
# Decision Tree Classifier trained on new_x_train4_std_knn
# Support Vector Classifier trained on new_x_train4_std_knn
# Naive Bayes Classifier trained on new_x_train4_std_knn
# Training models on dataset: x_train_5a
# Training regression models...
# Linear Regression trained on x_train_5a
# K-Neighbors Regressor trained on x_train_5a
# Decision Tree Regressor trained on x_train_5a
# Support Vector Regressor trained on x_train_5a
# Training classification models...
# Logistic Regression trained on x_train_5a
# K-Neighbors Classifier trained on x_train_5a
# Decision Tree Classifier trained on x_train_5a
# Support Vector Classifier trained on x_train_5a
# Naive Bayes Classifier trained on x_train_5a
# Training models on dataset: x_train_5b
# Training regression models...
# Linear Regression trained on x_train_5b
# K-Neighbors Regressor trained on x_train_5b
# Decision Tree Regressor trained on x_train_5b
# Support Vector Regressor trained on x_train_5b
# Training classification models...
# Logistic Regression trained on x_train_5b
# K-Neighbors Classifier trained on x_train_5b
# Decision Tree Classifier trained on x_train_5b
# Support Vector Classifier trained on x_train_5b
# Naive Bayes Classifier trained on x_train_5b
# Training models on dataset: x_train_6a
# Training regression models...
# Linear Regression trained on x_train_6a
# K-Neighbors Regressor trained on x_train_6a
# Decision Tree Regressor trained on x_train_6a
# Support Vector Regressor trained on x_train_6a
# Training classification models...
# Logistic Regression trained on x_train_6a
# K-Neighbors Classifier trained on x_train_6a
# Decision Tree Classifier trained on x_train_6a
# Support Vector Classifier trained on x_train_6a
# Naive Bayes Classifier trained on x_train_6a
# Training models on dataset: x_train_6b
# Training regression models...
# Linear Regression trained on x_train_6b
# K-Neighbors Regressor trained on x_train_6b
# Decision Tree Regressor trained on x_train_6b
# Support Vector Regressor trained on x_train_6b
# Training classification models...
# Logistic Regression trained on x_train_6b
# K-Neighbors Classifier trained on x_train_6b
# Decision Tree Classifier trained on x_train_6b
# Support Vector Classifier trained on x_train_6b
# Naive Bayes Classifier trained on x_train_6b
# Training completed.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Define your datasets
datasets = {
    "x_train3_std_mode": (x_train3_std_mode, y_train, x_test3_std_mode, y_test),
    "x_train3_std_knn": (x_train3_std_knn, y_train, x_test3_std_knn, y_test),
    "x_train4_std_mode": (x_train4_std_mode, y_train, x_test4_std_mode, y_test),
    "x_train4_std_knn": (x_train4_std_knn, y_train, x_test4_std_knn, y_test),
    "new_x_train3_std_mode": (new_x_train3_std_mode, y_train, new_x_test3_std_mode, y_test),
    "new_x_train3_std_knn": (new_x_train3_std_knn, y_train, new_x_test3_std_knn, y_test),
    "new_x_train4_std_mode": (new_x_train4_std_mode, y_train, new_x_test4_std_mode, y_test),
    "new_x_train4_std_knn": (new_x_train4_std_knn, y_train, new_x_test4_std_knn, y_test)
}

# Initialize dictionaries to store results
regression_results = {}
classification_results = {}

# Iterate over each dataset and train/test models
for dataset_name, (X_train, y_train, X_test, y_test) in datasets.items():
    print(f"Evaluating models on dataset: {dataset_name}")
    
    # Evaluate regression models
    for model_name, model in regression_models.items():
        model.fit(X_train, y_train)  # Train model
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)
        
        # Calculate metrics
        train_mae = mean_absolute_error(y_train, y_train_pred)
        train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
        train_r2 = r2_score(y_train, y_train_pred)
        
        test_mae = mean_absolute_error(y_test, y_test_pred)
        test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
        test_r2 = r2_score(y_test, y_test_pred)
        
        # Store results
        if dataset_name not in regression_results:
            regression_results[dataset_name] = {}
        regression_results[dataset_name][model_name] = {
            "Train MAE": train_mae,
            "Train RMSE": train_rmse,
            "Train R2": train_r2,
            "Test MAE": test_mae,
            "Test RMSE": test_rmse,
            "Test R2": test_r2
        }
        print(f"{model_name} - Train MAE: {train_mae:.4f}, Test MAE: {test_mae:.4f}")
        print(f"{model_name} - Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}")
        print(f"{model_name} - Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
        print("="*50)
    
    # Evaluate classification models
    for model_name, model in classification_models.items():
        model.fit(X_train, y_train)  # Train model
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)
        
        # Calculate Performance metrics
        train_accuracy = accuracy_score(y_train, y_train_pred)
        train_precision = precision_score(y_train, y_train_pred, average='weighted')
        train_recall = recall_score(y_train, y_train_pred, average='weighted')
        train_f1 = f1_score(y_train, y_train_pred, average='weighted')
        
        test_accuracy = accuracy_score(y_test, y_test_pred)
        test_precision = precision_score(y_test, y_test_pred, average='weighted')
        test_recall = recall_score(y_test, y_test_pred, average='weighted')
        test_f1 = f1_score(y_test, y_test_pred, average='weighted')
        
        # Storing Results here!
        if dataset_name not in classification_results:
            classification_results[dataset_name] = {}
        classification_results[dataset_name][model_name] = {
            "Train Accuracy": train_accuracy,
            "Train Precision": train_precision,
            "Train Recall": train_recall,
            "Train F1-score": train_f1,
            "Test Accuracy": test_accuracy,
            "Test Precision": test_precision,
            "Test Recall": test_recall,
            "Test F1-score": test_f1
        }
        print(f"{model_name} - Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print(f"{model_name} - Train Precision: {train_precision:.4f}, Test Precision: {test_precision:.4f}")
        print(f"{model_name} - Train Recall: {train_recall:.4f}, Test Recall: {test_recall:.4f}")
        print(f"{model_name} - Train F1-score: {train_f1:.4f}, Test F1-score: {test_f1:.4f}")
        print("="*50)
# Out:
# Evaluating models on dataset: x_train3_std_mode
# Linear Regression - Train MAE: 0.2638, Test MAE: 0.2811
# Linear Regression - Train RMSE: 0.3402, Test RMSE: 0.3512
# Linear Regression - Train R2: 0.5311, Test R2: 0.5065
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.2246, Test MAE: 0.2520
# K-Neighbors Regressor - Train RMSE: 0.3328, Test RMSE: 0.3731
# K-Neighbors Regressor - Train R2: 0.5513, Test R2: 0.4430
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2900
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5385
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.1605
# ==================================================
# Support Vector Regressor - Train MAE: 0.2068, Test MAE: 0.2366
# Support Vector Regressor - Train RMSE: 0.3122, Test RMSE: 0.3392
# Support Vector Regressor - Train R2: 0.6052, Test R2: 0.5396
# ==================================================
# Logistic Regression - Train Accuracy: 0.8473, Test Accuracy: 0.8700
# Logistic Regression - Train Precision: 0.8496, Test Precision: 0.8702
# Logistic Regression - Train Recall: 0.8473, Test Recall: 0.8700
# Logistic Regression - Train F1-score: 0.8459, Test F1-score: 0.8700
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8325, Test Accuracy: 0.8100
# K-Neighbors Classifier - Train Precision: 0.8339, Test Precision: 0.8100
# K-Neighbors Classifier - Train Recall: 0.8325, Test Recall: 0.8100
# K-Neighbors Classifier - Train F1-score: 0.8311, Test F1-score: 0.8099
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.6800
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.6834
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.6800
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.6792
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8500
# Support Vector Classifier - Train Precision: 0.8485, Test Precision: 0.8501
# Support Vector Classifier - Train Recall: 0.8424, Test Recall: 0.8500
# Support Vector Classifier - Train F1-score: 0.8399, Test F1-score: 0.8500
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8500
# Naive Bayes Classifier - Train Precision: 0.8431, Test Precision: 0.8502
# Naive Bayes Classifier - Train Recall: 0.8424, Test Recall: 0.8500
# Naive Bayes Classifier - Train F1-score: 0.8414, Test F1-score: 0.8500
# ==================================================
# Evaluating models on dataset: x_train3_std_knn
# Linear Regression - Train MAE: 0.2648, Test MAE: 0.2810
# Linear Regression - Train RMSE: 0.3407, Test RMSE: 0.3529
# Linear Regression - Train R2: 0.5298, Test R2: 0.5018
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.2256, Test MAE: 0.2480
# K-Neighbors Regressor - Train RMSE: 0.3319, Test RMSE: 0.3699
# K-Neighbors Regressor - Train R2: 0.5537, Test R2: 0.4526
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.3200
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5657
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.2805
# ==================================================
# Support Vector Regressor - Train MAE: 0.2073, Test MAE: 0.2370
# Support Vector Regressor - Train RMSE: 0.3122, Test RMSE: 0.3417
# Support Vector Regressor - Train R2: 0.6050, Test R2: 0.5327
# ==================================================
# Logistic Regression - Train Accuracy: 0.8424, Test Accuracy: 0.8600
# Logistic Regression - Train Precision: 0.8452, Test Precision: 0.8607
# Logistic Regression - Train Recall: 0.8424, Test Recall: 0.8600
# Logistic Regression - Train F1-score: 0.8407, Test F1-score: 0.8600
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8325, Test Accuracy: 0.8200
# K-Neighbors Classifier - Train Precision: 0.8339, Test Precision: 0.8200
# K-Neighbors Classifier - Train Recall: 0.8325, Test Recall: 0.8200
# K-Neighbors Classifier - Train F1-score: 0.8311, Test F1-score: 0.8200
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.6800
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.6834
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.6800
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.6792
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8374, Test Accuracy: 0.8500
# Support Vector Classifier - Train Precision: 0.8444, Test Precision: 0.8501
# Support Vector Classifier - Train Recall: 0.8374, Test Recall: 0.8500
# Support Vector Classifier - Train F1-score: 0.8346, Test F1-score: 0.8500
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8300
# Naive Bayes Classifier - Train Precision: 0.8431, Test Precision: 0.8302
# Naive Bayes Classifier - Train Recall: 0.8424, Test Recall: 0.8300
# Naive Bayes Classifier - Train F1-score: 0.8414, Test F1-score: 0.8300
# ==================================================
# Evaluating models on dataset: x_train4_std_mode
# Linear Regression - Train MAE: 0.2638, Test MAE: 0.2811
# Linear Regression - Train RMSE: 0.3402, Test RMSE: 0.3512
# Linear Regression - Train R2: 0.5311, Test R2: 0.5065
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.1901, Test MAE: 0.2380
# K-Neighbors Regressor - Train RMSE: 0.3085, Test RMSE: 0.3693
# K-Neighbors Regressor - Train R2: 0.6144, Test R2: 0.4542
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2500
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5000
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.0004
# ==================================================
# Support Vector Regressor - Train MAE: 0.2178, Test MAE: 0.2348
# Support Vector Regressor - Train RMSE: 0.3323, Test RMSE: 0.3467
# Support Vector Regressor - Train R2: 0.5526, Test R2: 0.5191
# ==================================================
# Logistic Regression - Train Accuracy: 0.8325, Test Accuracy: 0.8500
# Logistic Regression - Train Precision: 0.8351, Test Precision: 0.8514
# Logistic Regression - Train Recall: 0.8325, Test Recall: 0.8500
# Logistic Regression - Train F1-score: 0.8308, Test F1-score: 0.8500
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8621, Test Accuracy: 0.8100
# K-Neighbors Classifier - Train Precision: 0.8624, Test Precision: 0.8135
# K-Neighbors Classifier - Train Recall: 0.8621, Test Recall: 0.8100
# K-Neighbors Classifier - Train F1-score: 0.8615, Test F1-score: 0.8097
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.7300
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.7312
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.7300
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.7299
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8374, Test Accuracy: 0.8600
# Support Vector Classifier - Train Precision: 0.8424, Test Precision: 0.8625
# Support Vector Classifier - Train Recall: 0.8374, Test Recall: 0.8600
# Support Vector Classifier - Train F1-score: 0.8351, Test F1-score: 0.8599
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8500
# Naive Bayes Classifier - Train Precision: 0.8431, Test Precision: 0.8502
# Naive Bayes Classifier - Train Recall: 0.8424, Test Recall: 0.8500
# Naive Bayes Classifier - Train F1-score: 0.8414, Test F1-score: 0.8500
# ==================================================
# Evaluating models on dataset: x_train4_std_knn
# Linear Regression - Train MAE: 0.2648, Test MAE: 0.2810
# Linear Regression - Train RMSE: 0.3407, Test RMSE: 0.3529
# Linear Regression - Train R2: 0.5298, Test R2: 0.5018
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.1911, Test MAE: 0.2380
# K-Neighbors Regressor - Train RMSE: 0.3088, Test RMSE: 0.3661
# K-Neighbors Regressor - Train R2: 0.6136, Test R2: 0.4638
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2800
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5292
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.1204
# ==================================================
# Support Vector Regressor - Train MAE: 0.2187, Test MAE: 0.2389
# Support Vector Regressor - Train RMSE: 0.3322, Test RMSE: 0.3499
# Support Vector Regressor - Train R2: 0.5527, Test R2: 0.5101
# ==================================================
# Logistic Regression - Train Accuracy: 0.8325, Test Accuracy: 0.8400
# Logistic Regression - Train Precision: 0.8351, Test Precision: 0.8424
# Logistic Regression - Train Recall: 0.8325, Test Recall: 0.8400
# Logistic Regression - Train F1-score: 0.8308, Test F1-score: 0.8399
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8621, Test Accuracy: 0.8100
# K-Neighbors Classifier - Train Precision: 0.8624, Test Precision: 0.8135
# K-Neighbors Classifier - Train Recall: 0.8621, Test Recall: 0.8100
# K-Neighbors Classifier - Train F1-score: 0.8615, Test F1-score: 0.8097
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.6700
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.6710
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.6700
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.6699
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8325, Test Accuracy: 0.8700
# Support Vector Classifier - Train Precision: 0.8365, Test Precision: 0.8715
# Support Vector Classifier - Train Recall: 0.8325, Test Recall: 0.8700
# Support Vector Classifier - Train F1-score: 0.8303, Test F1-score: 0.8700
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8300
# Naive Bayes Classifier - Train Precision: 0.8431, Test Precision: 0.8302
# Naive Bayes Classifier - Train Recall: 0.8424, Test Recall: 0.8300
# Naive Bayes Classifier - Train F1-score: 0.8414, Test F1-score: 0.8300
# ==================================================
# Evaluating models on dataset: new_x_train3_std_mode
# Linear Regression - Train MAE: 0.2647, Test MAE: 0.2807
# Linear Regression - Train RMSE: 0.3417, Test RMSE: 0.3556
# Linear Regression - Train R2: 0.5269, Test R2: 0.4940
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.2030, Test MAE: 0.2300
# K-Neighbors Regressor - Train RMSE: 0.3207, Test RMSE: 0.3527
# K-Neighbors Regressor - Train R2: 0.5832, Test R2: 0.5022
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2800
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5292
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.1204
# ==================================================
# Support Vector Regressor - Train MAE: 0.2099, Test MAE: 0.2365
# Support Vector Regressor - Train RMSE: 0.3205, Test RMSE: 0.3409
# Support Vector Regressor - Train R2: 0.5839, Test R2: 0.5349
# ==================================================
# Logistic Regression - Train Accuracy: 0.8374, Test Accuracy: 0.8500
# Logistic Regression - Train Precision: 0.8408, Test Precision: 0.8514
# Logistic Regression - Train Recall: 0.8374, Test Recall: 0.8500
# Logistic Regression - Train F1-score: 0.8355, Test F1-score: 0.8500
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8276, Test Accuracy: 0.8500
# K-Neighbors Classifier - Train Precision: 0.8285, Test Precision: 0.8538
# K-Neighbors Classifier - Train Recall: 0.8276, Test Recall: 0.8500
# K-Neighbors Classifier - Train F1-score: 0.8264, Test F1-score: 0.8498
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.6900
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.6911
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.6900
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.6899
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8700
# Support Vector Classifier - Train Precision: 0.8485, Test Precision: 0.8715
# Support Vector Classifier - Train Recall: 0.8424, Test Recall: 0.8700
# Support Vector Classifier - Train F1-score: 0.8399, Test F1-score: 0.8700
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8522, Test Accuracy: 0.8400
# Naive Bayes Classifier - Train Precision: 0.8531, Test Precision: 0.8407
# Naive Bayes Classifier - Train Recall: 0.8522, Test Recall: 0.8400
# Naive Bayes Classifier - Train F1-score: 0.8513, Test F1-score: 0.8400
# ==================================================
# Evaluating models on dataset: new_x_train3_std_knn
# Linear Regression - Train MAE: 0.2661, Test MAE: 0.2800
# Linear Regression - Train RMSE: 0.3422, Test RMSE: 0.3561
# Linear Regression - Train R2: 0.5254, Test R2: 0.4925
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.2020, Test MAE: 0.2400
# K-Neighbors Regressor - Train RMSE: 0.3085, Test RMSE: 0.3655
# K-Neighbors Regressor - Train R2: 0.6144, Test R2: 0.4654
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2800
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5292
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.1204
# ==================================================
# Support Vector Regressor - Train MAE: 0.2121, Test MAE: 0.2353
# Support Vector Regressor - Train RMSE: 0.3193, Test RMSE: 0.3471
# Support Vector Regressor - Train R2: 0.5870, Test R2: 0.5178
# ==================================================
# Logistic Regression - Train Accuracy: 0.8374, Test Accuracy: 0.8400
# Logistic Regression - Train Precision: 0.8408, Test Precision: 0.8424
# Logistic Regression - Train Recall: 0.8374, Test Recall: 0.8400
# Logistic Regression - Train F1-score: 0.8355, Test F1-score: 0.8399
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8571, Test Accuracy: 0.8300
# K-Neighbors Classifier - Train Precision: 0.8597, Test Precision: 0.8302
# K-Neighbors Classifier - Train Recall: 0.8571, Test Recall: 0.8300
# K-Neighbors Classifier - Train F1-score: 0.8558, Test F1-score: 0.8300
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.7100
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.7127
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.7100
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.7096
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8424, Test Accuracy: 0.8600
# Support Vector Classifier - Train Precision: 0.8485, Test Precision: 0.8607
# Support Vector Classifier - Train Recall: 0.8424, Test Recall: 0.8600
# Support Vector Classifier - Train F1-score: 0.8399, Test F1-score: 0.8600
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8374, Test Accuracy: 0.8700
# Naive Bayes Classifier - Train Precision: 0.8385, Test Precision: 0.8702
# Naive Bayes Classifier - Train Recall: 0.8374, Test Recall: 0.8700
# Naive Bayes Classifier - Train F1-score: 0.8363, Test F1-score: 0.8700
# ==================================================
# Evaluating models on dataset: new_x_train4_std_mode
# Linear Regression - Train MAE: 0.2620, Test MAE: 0.2812
# Linear Regression - Train RMSE: 0.3412, Test RMSE: 0.3543
# Linear Regression - Train R2: 0.5282, Test R2: 0.4978
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.1842, Test MAE: 0.2460
# K-Neighbors Regressor - Train RMSE: 0.3033, Test RMSE: 0.3831
# K-Neighbors Regressor - Train R2: 0.6271, Test R2: 0.4126
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.3000
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5477
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.2005
# ==================================================
# Support Vector Regressor - Train MAE: 0.2156, Test MAE: 0.2364
# Support Vector Regressor - Train RMSE: 0.3317, Test RMSE: 0.3497
# Support Vector Regressor - Train R2: 0.5543, Test R2: 0.5106
# ==================================================
# Logistic Regression - Train Accuracy: 0.8374, Test Accuracy: 0.8500
# Logistic Regression - Train Precision: 0.8385, Test Precision: 0.8502
# Logistic Regression - Train Recall: 0.8374, Test Recall: 0.8500
# Logistic Regression - Train F1-score: 0.8363, Test F1-score: 0.8500
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8473, Test Accuracy: 0.8300
# K-Neighbors Classifier - Train Precision: 0.8478, Test Precision: 0.8337
# K-Neighbors Classifier - Train Recall: 0.8473, Test Recall: 0.8300
# K-Neighbors Classifier - Train F1-score: 0.8465, Test F1-score: 0.8297
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.7600
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.7600
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.7600
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.7600
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8374, Test Accuracy: 0.8600
# Support Vector Classifier - Train Precision: 0.8424, Test Precision: 0.8625
# Support Vector Classifier - Train Recall: 0.8374, Test Recall: 0.8600
# Support Vector Classifier - Train F1-score: 0.8351, Test F1-score: 0.8599
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8325, Test Accuracy: 0.8700
# Naive Bayes Classifier - Train Precision: 0.8331, Test Precision: 0.8702
# Naive Bayes Classifier - Train Recall: 0.8325, Test Recall: 0.8700
# Naive Bayes Classifier - Train F1-score: 0.8315, Test F1-score: 0.8700
# ==================================================
# Evaluating models on dataset: new_x_train4_std_knn
# Linear Regression - Train MAE: 0.2659, Test MAE: 0.2810
# Linear Regression - Train RMSE: 0.3423, Test RMSE: 0.3573
# Linear Regression - Train R2: 0.5254, Test R2: 0.4891
# ==================================================
# K-Neighbors Regressor - Train MAE: 0.1695, Test MAE: 0.2300
# K-Neighbors Regressor - Train RMSE: 0.2918, Test RMSE: 0.3639
# K-Neighbors Regressor - Train R2: 0.6551, Test R2: 0.4702
# ==================================================
# Decision Tree Regressor - Train MAE: 0.0000, Test MAE: 0.2700
# Decision Tree Regressor - Train RMSE: 0.0000, Test RMSE: 0.5196
# Decision Tree Regressor - Train R2: 1.0000, Test R2: -0.0804
# ==================================================
# Support Vector Regressor - Train MAE: 0.2189, Test MAE: 0.2437
# Support Vector Regressor - Train RMSE: 0.3359, Test RMSE: 0.3552
# Support Vector Regressor - Train R2: 0.5427, Test R2: 0.4952
# ==================================================
# Logistic Regression - Train Accuracy: 0.8325, Test Accuracy: 0.8300
# Logistic Regression - Train Precision: 0.8351, Test Precision: 0.8314
# Logistic Regression - Train Recall: 0.8325, Test Recall: 0.8300
# Logistic Regression - Train F1-score: 0.8308, Test F1-score: 0.8299
# ==================================================
# K-Neighbors Classifier - Train Accuracy: 0.8768, Test Accuracy: 0.8300
# K-Neighbors Classifier - Train Precision: 0.8771, Test Precision: 0.8416
# K-Neighbors Classifier - Train Recall: 0.8768, Test Recall: 0.8300
# K-Neighbors Classifier - Train F1-score: 0.8764, Test F1-score: 0.8289
# ==================================================
# Decision Tree Classifier - Train Accuracy: 1.0000, Test Accuracy: 0.7100
# Decision Tree Classifier - Train Precision: 1.0000, Test Precision: 0.7111
# Decision Tree Classifier - Train Recall: 1.0000, Test Recall: 0.7100
# Decision Tree Classifier - Train F1-score: 1.0000, Test F1-score: 0.7099
# ==================================================
# Support Vector Classifier - Train Accuracy: 0.8374, Test Accuracy: 0.8500
# Support Vector Classifier - Train Precision: 0.8444, Test Precision: 0.8514
# Support Vector Classifier - Train Recall: 0.8374, Test Recall: 0.8500
# Support Vector Classifier - Train F1-score: 0.8346, Test F1-score: 0.8500
# ==================================================
# Naive Bayes Classifier - Train Accuracy: 0.8522, Test Accuracy: 0.8300
# Naive Bayes Classifier - Train Precision: 0.8531, Test Precision: 0.8314
# Naive Bayes Classifier - Train Recall: 0.8522, Test Recall: 0.8300
# Naive Bayes Classifier - Train F1-score: 0.8513, Test F1-score: 0.8299
# ==================================================

# %% [markdown]
# ## Model Testing
